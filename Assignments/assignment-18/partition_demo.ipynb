# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("PartitionDemo") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/14 15:09:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.range(5000000)
# Out:
# 26/06/14 15:09:34 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
print("Initial Partitions:", df.rdd.getNumPartitions())
# Out:
# Initial Partitions: 2

# %%
df_repartition = df.repartition(12)

# %%
print("Partitions After Repartition:", df_repartition.rdd.getNumPartitions())
# Out:
# [Stage 0:>                                                          (0 + 2) / 2]
# Partitions After Repartition: 12

# %%
df_coalesce = df_repartition.coalesce(3)

# %%
print("Partitions After Coalesce:", df_coalesce.rdd.getNumPartitions())
# Out:
# [Stage 1:>                                                          (0 + 2) / 2]
# Partitions After Coalesce: 3

# %%
spark.stop()
